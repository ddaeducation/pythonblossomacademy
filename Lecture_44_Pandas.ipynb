# %% [markdown]
# # Pandas: Data Wrangling
#
# ## Introduction
#
# Pandas is an essential library for data wrangling, transformation, and exploration in Python. This notebook expands on key functionality using realistic African-centric data examples.

# %%
import pandas as pd

# %%
Household=pd.read_csv("African_Household_Data.csv")
Household
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0     Rwanda   20           1235                     166        6741
# 1      Ghana   68           4637                      98       14281
# 2     Rwanda   48            301                     238        7838
# 3     Rwanda   57           3148                     262        3587
# 4      Ghana   54           4344                     124        8876
# ..       ...  ...            ...                     ...         ...
# 995  Nigeria   39            489                     175       10021
# 996  Nigeria   45           1280                     132        2909
# 997   Rwanda   37           1998                     172        7364
# 998   Rwanda   50           2015                     235        3581
# 999    Ghana   27           2893                     207        1691
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0              1440                  42               2      Secondary
# 1               981                  39               3      Secondary
# 2               890                  43               2       Tertiary
# 3              1060                  39               1      Secondary
# 4               631                  31               2      Secondary
# ..              ...                 ...             ...            ...
# 995             220                  35               2        Primary
# 996             344                  34               2       Tertiary
# 997             238                  42               2      Secondary
# 998             475                  25               0       Tertiary
# 999            1026                  52               2      Secondary
#
#      RainfallMM District
# 0     72.886134  Central
# 1    178.878356     East
# 2    120.131577     East
# 3    110.633007    North
# 4    117.422414  Central
# ..          ...      ...
# 995   98.783179     West
# 996  188.507700  Central
# 997  112.602188     East
# 998  194.429350  Central
# 999   53.625553    South
#
# [1000 rows x 11 columns]

# %%
Household.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District
# 0   72.886134  Central
# 1  178.878356     East
# 2  120.131577     East
# 3  110.633007    North
# 4  117.422414  Central

# %%
Household.tail()
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 995  Nigeria   39            489                     175       10021
# 996  Nigeria   45           1280                     132        2909
# 997   Rwanda   37           1998                     172        7364
# 998   Rwanda   50           2015                     235        3581
# 999    Ghana   27           2893                     207        1691
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 995             220                  35               2        Primary
# 996             344                  34               2       Tertiary
# 997             238                  42               2      Secondary
# 998             475                  25               0       Tertiary
# 999            1026                  52               2      Secondary
#
#      RainfallMM District
# 995   98.783179     West
# 996  188.507700  Central
# 997  112.602188     East
# 998  194.429350  Central
# 999   53.625553    South

# %% [markdown]
# ## PART ONE

# %% [markdown]
# ### 1. Creating a DataFrame

# %%
data = {
    'Country': ['Nigeria', 'Kenya', 'Ghana', 'South Africa', 'Egypt'],
    'Population': [213400000, 53770000, 31070000, 60410000, 104000000],
    'Area': [923768, 580367, 238535, 1219090, 1002450],
    'Capital': ['Abuja', 'Nairobi', 'Accra', 'Pretoria', 'Cairo']
}
df = pd.DataFrame(data)
df
# Out:
#         Country  Population     Area   Capital
# 0       Nigeria   213400000   923768     Abuja
# 1         Kenya    53770000   580367   Nairobi
# 2         Ghana    31070000   238535     Accra
# 3  South Africa    60410000  1219090  Pretoria
# 4         Egypt   104000000  1002450     Cairo

# %% [markdown]
# ### 2. Using `.loc[]` for Label-based Indexing

# %%
df.loc[1]  # Second row by label
# Out:
# Country          Kenya
# Population    53770000
# Area            580367
# Capital        Nairobi
# Name: 1, dtype: object

# %% [markdown]
# ### 3. Using `.iloc[]` for Position-based Indexing

# %%
df.iloc[2]  # Third row by index position
# Out:
# Country          Ghana
# Population    31070000
# Area            238535
# Capital          Accra
# Name: 2, dtype: object

# %% [markdown]
# ### 4. Filtering with Conditions and `.loc[]`

# %%
df.loc[df['Population'] > 60000000, ['Country', 'Population']]
# Out:
#         Country  Population
# 0       Nigeria   213400000
# 3  South Africa    60410000
# 4         Egypt   104000000

# %% [markdown]
# ### 5. Renaming Columns

# %%
df.rename(columns={'Population': 'Population_Total', 'Area': 'Land_Area_km2'}, inplace=True)
df
# Out:
#         Country  Population_Total  Land_Area_km2   Capital
# 0       Nigeria         213400000         923768     Abuja
# 1         Kenya          53770000         580367   Nairobi
# 2         Ghana          31070000         238535     Accra
# 3  South Africa          60410000        1219090  Pretoria
# 4         Egypt         104000000        1002450     Cairo

# %% [markdown]
# ### 6. Adding New Columns

# %%
df['Density'] = df['Population_Total'] / df['Land_Area_km2']
df
# Out:
#         Country  Population_Total  Land_Area_km2   Capital     Density
# 0       Nigeria         213400000         923768     Abuja  231.010384
# 1         Kenya          53770000         580367   Nairobi   92.648273
# 2         Ghana          31070000         238535     Accra  130.253422
# 3  South Africa          60410000        1219090  Pretoria   49.553355
# 4         Egypt         104000000        1002450     Cairo  103.745823

# %% [markdown]
# ### 7. Replacing Values

# %%
df['Capital'] = df['Capital'].replace({'Pretoria': 'Cape Town'})
df
# Out:
#         Country  Population_Total  Land_Area_km2    Capital     Density
# 0       Nigeria         213400000         923768      Abuja  231.010384
# 1         Kenya          53770000         580367    Nairobi   92.648273
# 2         Ghana          31070000         238535      Accra  130.253422
# 3  South Africa          60410000        1219090  Cape Town   49.553355
# 4         Egypt         104000000        1002450      Cairo  103.745823

# %% [markdown]
# ### 8. Setting and Resetting Index

# %%
df.set_index('Country', inplace=True)
df.head()
# Out:
#               Population_Total  Land_Area_km2    Capital     Density
# Country
# Nigeria              213400000         923768      Abuja  231.010384
# Kenya                 53770000         580367    Nairobi   92.648273
# Ghana                 31070000         238535      Accra  130.253422
# South Africa          60410000        1219090  Cape Town   49.553355
# Egypt                104000000        1002450      Cairo  103.745823

# %%
df.reset_index(inplace=True)  # Restore default integer index
df.head()
# Out:
#         Country  Population_Total  Land_Area_km2    Capital     Density
# 0       Nigeria         213400000         923768      Abuja  231.010384
# 1         Kenya          53770000         580367    Nairobi   92.648273
# 2         Ghana          31070000         238535      Accra  130.253422
# 3  South Africa          60410000        1219090  Cape Town   49.553355
# 4         Egypt         104000000        1002450      Cairo  103.745823

# %% [markdown]
# ### 9. Sorting by a Column

# %%
df.sort_values(by='Density', ascending=False)
# Out:
#         Country  Population_Total  Land_Area_km2    Capital     Density
# 0       Nigeria         213400000         923768      Abuja  231.010384
# 2         Ghana          31070000         238535      Accra  130.253422
# 4         Egypt         104000000        1002450      Cairo  103.745823
# 1         Kenya          53770000         580367    Nairobi   92.648273
# 3  South Africa          60410000        1219090  Cape Town   49.553355

# %% [markdown]
# ### 10. Using `.apply()` with Custom Functions

# %%
def size_category(area):
    if area > 900000:
        return 'Large'
    elif area > 500000:
        return 'Medium'
    else:
        return 'Small'

df['Area_Category'] = df['Land_Area_km2'].apply(size_category)
df
# Out:
#         Country  Population_Total  Land_Area_km2    Capital     Density  \
# 0       Nigeria         213400000         923768      Abuja  231.010384
# 1         Kenya          53770000         580367    Nairobi   92.648273
# 2         Ghana          31070000         238535      Accra  130.253422
# 3  South Africa          60410000        1219090  Cape Town   49.553355
# 4         Egypt         104000000        1002450      Cairo  103.745823
#
#   Area_Category
# 0         Large
# 1        Medium
# 2         Small
# 3         Large
# 4         Large

# %% [markdown]
# ### 11. Export to CSV

# %%
df.to_csv('african_country_data.csv', index=False)

# %% [markdown]
# # PART TWO

# %%
df = pd.read_csv('African_Household_Data.csv')

# %%
df.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District
# 0   72.886134  Central
# 1  178.878356     East
# 2  120.131577     East
# 3  110.633007    North
# 4  117.422414  Central

# %% [markdown]
# ## Data Inspection and Basic Operations

# %% [markdown]
# ### 1. Display first 5 rows

# %%
df.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District
# 0   72.886134  Central
# 1  178.878356     East
# 2  120.131577     East
# 3  110.633007    North
# 4  117.422414  Central

# %% [markdown]
# ### 2. Display last 5 rows

# %%
df.tail()
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 995  Nigeria   39            489                     175       10021
# 996  Nigeria   45           1280                     132        2909
# 997   Rwanda   37           1998                     172        7364
# 998   Rwanda   50           2015                     235        3581
# 999    Ghana   27           2893                     207        1691
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 995             220                  35               2        Primary
# 996             344                  34               2       Tertiary
# 997             238                  42               2      Secondary
# 998             475                  25               0       Tertiary
# 999            1026                  52               2      Secondary
#
#      RainfallMM District
# 995   98.783179     West
# 996  188.507700  Central
# 997  112.602188     East
# 998  194.429350  Central
# 999   53.625553    South

# %% [markdown]
# ### 3. Show basic info about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 1000 non-null   object
#  1   Age                     1000 non-null   int64
#  2   MonthlyIncome           1000 non-null   int64
#  3   ElectricityConsumption  1000 non-null   int64
#  4   CocoaSales              1000 non-null   int64
#  5   TransportCosts          1000 non-null   int64
#  6   InternetUsageHours      1000 non-null   int64
#  7   HospitalVisits          1000 non-null   int64
#  8   EducationLevel          1000 non-null   object
#  9   RainfallMM              1000 non-null   float64
#  10  District                1000 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %% [markdown]
# ### 4. Show summary statistics

# %%
df.describe()
# Out:
#                Age  MonthlyIncome  ElectricityConsumption    CocoaSales  \
# count  1000.000000    1000.000000             1000.000000   1000.000000
# mean     43.645000    2604.006000              198.961000   7973.312000
# std      14.810886    1346.366415               49.703621   4097.837958
# min      18.000000     301.000000               26.000000   1016.000000
# 25%      31.000000    1416.750000              165.000000   4306.750000
# 50%      44.000000    2620.000000              200.000000   7878.000000
# 75%      56.000000    3786.000000              235.000000  11541.750000
# max      69.000000    4997.000000              336.000000  14998.000000
#
#        TransportCosts  InternetUsageHours  HospitalVisits   RainfallMM
# count     1000.000000         1000.000000     1000.000000  1000.000000
# mean       775.685000           38.858000        1.900000   126.171131
# std        422.173239            9.738412        1.292931    42.789161
# min         50.000000            8.000000        0.000000    50.027779
# 25%        392.750000           32.000000        1.000000    91.837039
# 50%        758.000000           39.000000        2.000000   125.740065
# 75%       1161.000000           45.000000        3.000000   162.181174
# max       1499.000000           71.000000        8.000000   199.904740

# %% [markdown]
# ### 5. List column names

# %%
df.columns
# Out:
# Index(['Country', 'Age', 'MonthlyIncome', 'ElectricityConsumption',
#        'CocoaSales', 'TransportCosts', 'InternetUsageHours', 'HospitalVisits',
#        'EducationLevel', 'RainfallMM', 'District'],
#       dtype='object')

# %% [markdown]
# ### 6. Check shape (rows, columns)

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# ### 7. Check for missing values

# %%
df.isnull().sum()
# Out:
# Country                   0
# Age                       0
# MonthlyIncome             0
# ElectricityConsumption    0
# CocoaSales                0
# TransportCosts            0
# InternetUsageHours        0
# HospitalVisits            0
# EducationLevel            0
# RainfallMM                0
# District                  0
# dtype: int64

# %% [markdown]
# ### 8. View data types of each column

# %%
df.dtypes
# Out:
# Country                    object
# Age                         int64
# MonthlyIncome               int64
# ElectricityConsumption      int64
# CocoaSales                  int64
# TransportCosts              int64
# InternetUsageHours          int64
# HospitalVisits              int64
# EducationLevel             object
# RainfallMM                float64
# District                   object
# dtype: object

# %% [markdown]
# ### 9. Get unique countries

# %%
df['EducationLevel'].head()
# Out:
# 0    Secondary
# 1    Secondary
# 2     Tertiary
# 3    Secondary
# 4    Secondary
# Name: EducationLevel, dtype: object

# %%
df[["RainfallMM","InternetUsageHours","District"]].head()
# Out:
#    RainfallMM  InternetUsageHours District
# 0   72.886134                  42  Central
# 1  178.878356                  39     East
# 2  120.131577                  43     East
# 3  110.633007                  39    North
# 4  117.422414                  31  Central

# %%
df['Country'].unique()
# Out:
# array(['Rwanda', 'Ghana', 'Nigeria'], dtype=object)

# %%
df['Country'].nunique()
# Out:
# 3

# %% [markdown]
# ### 10. Get number of unique values in each column

# %%
df.nunique()
# Out:
# Country                      3
# Age                         52
# MonthlyIncome              896
# ElectricityConsumption     218
# CocoaSales                 964
# TransportCosts             721
# InternetUsageHours          56
# HospitalVisits               8
# EducationLevel               3
# RainfallMM                1000
# District                     5
# dtype: int64

# %% [markdown]
# ## Filtering and Conditional Selection

# %% [markdown]
# ### 11. Filter rows where Country is Ghana

# %%
df[df["Country"]=='Ghana']
# Out:
#     Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 1     Ghana   68           4637                      98       14281
# 4     Ghana   54           4344                     124        8876
# 5     Ghana   53           2249                     262        4262
# 12    Ghana   28           4538                     259        6232
# 15    Ghana   23           1186                     226        8845
# ..      ...  ...            ...                     ...         ...
# 984   Ghana   28           2804                     139        3965
# 985   Ghana   39           3072                     234        5319
# 986   Ghana   68           1454                     266        9975
# 988   Ghana   58           4871                     253       10141
# 999   Ghana   27           2893                     207        1691
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 1               981                  39               3      Secondary
# 4               631                  31               2      Secondary
# 5              1189                  48               5      Secondary
# 12              437                  50               1      Secondary
# 15              687                  32               3        Primary
# ..              ...                 ...             ...            ...
# 984             851                  40               1      Secondary
# 985             923                  44               3       Tertiary
# 986             521                  56               2        Primary
# 988             674                  41               0       Tertiary
# 999            1026                  52               2      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 1    178.878356     East     602.81         False       3656    61-70
# 4    117.422414  Central     564.72         False       3713    46-60
# 5    195.788683  Central     292.37          True       1060    46-60
# 12    91.813370     West     589.94          True       4101    18-30
# 15   108.060097     East     154.18         False        499    18-30
# ..          ...      ...        ...           ...        ...      ...
# 984  145.942569    South     364.52         False       1953    18-30
# 985  124.333354     West     399.36         False       2149    31-45
# 986   52.681030    North     189.02          True        933    61-70
# 988   77.580986    North     633.23          True       4197    46-60
# 999   53.625553    South     376.09         False       1867    18-30
#
# [355 rows x 15 columns]

# %%
df[df['Country'] == 'Ghana']
# Out:
#     Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 1     Ghana   68           4637                      98       14281
# 4     Ghana   54           4344                     124        8876
# 5     Ghana   53           2249                     262        4262
# 12    Ghana   28           4538                     259        6232
# 15    Ghana   23           1186                     226        8845
# ..      ...  ...            ...                     ...         ...
# 984   Ghana   28           2804                     139        3965
# 985   Ghana   39           3072                     234        5319
# 986   Ghana   68           1454                     266        9975
# 988   Ghana   58           4871                     253       10141
# 999   Ghana   27           2893                     207        1691
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 1               981                  39               3      Secondary
# 4               631                  31               2      Secondary
# 5              1189                  48               5      Secondary
# 12              437                  50               1      Secondary
# 15              687                  32               3        Primary
# ..              ...                 ...             ...            ...
# 984             851                  40               1      Secondary
# 985             923                  44               3       Tertiary
# 986             521                  56               2        Primary
# 988             674                  41               0       Tertiary
# 999            1026                  52               2      Secondary
#
#      RainfallMM District
# 1    178.878356     East
# 4    117.422414  Central
# 5    195.788683  Central
# 12    91.813370     West
# 15   108.060097     East
# ..          ...      ...
# 984  145.942569    South
# 985  124.333354     West
# 986   52.681030    North
# 988   77.580986    North
# 999   53.625553    South
#
# [355 rows x 11 columns]

# %% [markdown]
# ### 12. People older than 50

# %%
older_50 = df[df['Age'] > 50]

# %%
older_50
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 1      Ghana   68           4637                      98       14281
# 3     Rwanda   57           3148                     262        3587
# 4      Ghana   54           4344                     124        8876
# 5      Ghana   53           2249                     262        4262
# 16   Nigeria   66            727                     174       10229
# ..       ...  ...            ...                     ...         ...
# 981    Ghana   55            945                     170        5926
# 982  Nigeria   58           3290                     109       10379
# 986    Ghana   68           1454                     266        9975
# 988    Ghana   58           4871                     253       10141
# 991   Rwanda   63           4379                     216        2810
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 1               981                  39               3      Secondary
# 3              1060                  39               1      Secondary
# 4               631                  31               2      Secondary
# 5              1189                  48               5      Secondary
# 16              327                  22               1       Tertiary
# ..              ...                 ...             ...            ...
# 981            1178                  47               0      Secondary
# 982             277                  45               1        Primary
# 986             521                  56               2        Primary
# 988             674                  41               0       Tertiary
# 991             743                  40               5      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 1    178.878356     East     602.81         False       3656    61-70
# 3    110.633007    North     409.24          True       2088    46-60
# 4    117.422414  Central     564.72         False       3713    46-60
# 5    195.788683  Central     292.37          True       1060    46-60
# 16   134.396150     West      94.51         False        400    61-70
# ..          ...      ...        ...           ...        ...      ...
# 981  122.281008    North     122.85         False       -233    46-60
# 982  134.464142     West     427.70         False       3013    46-60
# 986   52.681030    North     189.02          True        933    61-70
# 988   77.580986    North     633.23          True       4197    46-60
# 991  134.570509    North     569.27         False       3636    61-70
#
# [367 rows x 15 columns]

# %%
df[(df['MonthlyIncome'] > 4000)&(df["Country"]=="Nigeria")].head()
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 63   Nigeria   54           4944                     210        8389
# 73   Nigeria   48           4188                     232       10136
# 79   Nigeria   28           4911                     182       12115
# 111  Nigeria   57           4305                     171        3259
# 119  Nigeria   50           4899                     213       11846
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 63              608                  42               1      Secondary
# 73             1244                  34               6        Primary
# 79              539                  43               2       Tertiary
# 111            1395                  49               2       Tertiary
# 119             837                  42               3        Primary
#
#      RainfallMM District
# 63   152.856084    South
# 73    61.199247    North
# 79    88.466603     East
# 111  168.951546    North
# 119  136.291939     East

# %%
df['MonthlyIncome'] > 4000
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: MonthlyIncome, Length: 1000, dtype: bool

# %%
df["Country"]=="Nigeria"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Country, Length: 1000, dtype: bool

# %% [markdown]
# ### 13. Households with monthly income over 3000 in Nigeria

# %%
df[(df['MonthlyIncome'] > 3000) & (df['Country'] == 'Nigeria')]
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 7    Nigeria   48           3474                     261        5996
# 22   Nigeria   28           3444                     251        7837
# 46   Nigeria   30           3895                     244        8086
# 60   Nigeria   19           3965                     221        2319
# 63   Nigeria   54           4944                     210        8389
# ..       ...  ...            ...                     ...         ...
# 969  Nigeria   35           4011                     185        6555
# 973  Nigeria   64           4164                     206        4092
# 977  Nigeria   28           3847                     215        8478
# 982  Nigeria   58           3290                     109       10379
# 992  Nigeria   49           3648                     281        5566
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 7              1408                  40               4        Primary
# 22              184                  38               3      Secondary
# 46              976                  31               1        Primary
# 60             1421                  36               0       Tertiary
# 63              608                  42               1      Secondary
# ..              ...                 ...             ...            ...
# 969             146                  35               2      Secondary
# 973            1333                  39               2      Secondary
# 977             108                  49               3        Primary
# 982             277                  45               1        Primary
# 992            1022                  51               5       Tertiary
#
#      RainfallMM District
# 7    155.955316     West
# 22   176.521875    South
# 46   188.268385    South
# 60   108.904867    South
# 63   152.856084    South
# ..          ...      ...
# 969  178.421923     West
# 973  184.157461    South
# 977   74.156932  Central
# 982  134.464142     West
# 992   81.594758     East
#
# [124 rows x 11 columns]

# %% [markdown]
# ### 14. Users with InternetUsageHours less than 20

# %%
df[df['InternetUsageHours']<= 20].head()
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 20     Ghana   19           2225                     103        4226
# 49   Nigeria   50           1566                     180        5749
# 128   Rwanda   68            327                     241        7953
# 135   Rwanda   68           4696                     169        3411
# 185    Ghana   43            425                     178        3011
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 20              698                  19               1       Tertiary
# 49              178                  20               1        Primary
# 128            1151                  18               1      Secondary
# 135            1413                  20               0       Tertiary
# 185             904                  16               2      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 20   199.178862    North     289.25         False       1527    18-30
# 49   187.618433     East     203.58         False       1388    46-60
# 128  126.509034    South      42.51         False       -824    61-70
# 135  174.773618    South     610.48         False       3283    61-70
# 185  123.214552  Central      55.25         False       -479    31-45

# %% [markdown]
# ### 15. People from Central or East districts

# %%
df[df['District'].isin(['Central', 'East', 'North','Kigali'])]
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0     Rwanda   20           1235                     166        6741
# 1      Ghana   68           4637                      98       14281
# 2     Rwanda   48            301                     238        7838
# 3     Rwanda   57           3148                     262        3587
# 4      Ghana   54           4344                     124        8876
# ..       ...  ...            ...                     ...         ...
# 992  Nigeria   49           3648                     281        5566
# 993   Rwanda   32           4131                     287       11273
# 996  Nigeria   45           1280                     132        2909
# 997   Rwanda   37           1998                     172        7364
# 998   Rwanda   50           2015                     235        3581
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0              1440                  42               2      Secondary
# 1               981                  39               3      Secondary
# 2               890                  43               2       Tertiary
# 3              1060                  39               1      Secondary
# 4               631                  31               2      Secondary
# ..              ...                 ...             ...            ...
# 992            1022                  51               5       Tertiary
# 993             162                  37               3        Primary
# 996             344                  34               2       Tertiary
# 997             238                  42               2      Secondary
# 998             475                  25               0       Tertiary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 0     72.886134  Central     160.55         False       -205    18-30
# 1    178.878356     East     602.81         False       3656    61-70
# 2    120.131577     East      39.13         False       -589    46-60
# 3    110.633007    North     409.24          True       2088    46-60
# 4    117.422414  Central     564.72         False       3713    46-60
# ..          ...      ...        ...           ...        ...      ...
# 992   81.594758     East     474.24          True       2626    46-60
# 993  192.326876     East     537.03          True       3969    31-45
# 996  188.507700  Central     166.40         False        936    31-45
# 997  112.602188     East     259.74         False       1760    31-45
# 998  194.429350  Central     261.95         False       1540    46-60
#
# [579 rows x 15 columns]

# %% [markdown]
# ### 16. People with tertiary education in Rwanda

# %%
df[(df['EducationLevel'] == 'Tertiary') & (df['Country'] == 'Rwanda')]
# Out:
#     Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 2    Rwanda   48            301                     238        7838
# 9    Rwanda   19            389                     206        6780
# 11   Rwanda   45           2469                     160       14873
# 28   Rwanda   22           2013                     213        4414
# 41   Rwanda   31            709                     221        2678
# ..      ...  ...            ...                     ...         ...
# 938  Rwanda   67           3639                     257       14374
# 945  Rwanda   20           3276                     197        6956
# 950  Rwanda   47           3990                     149       13917
# 967  Rwanda   25           1894                     258       13515
# 998  Rwanda   50           2015                     235        3581
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 2               890                  43               2       Tertiary
# 9               197                  53               2       Tertiary
# 11             1361                  34               2       Tertiary
# 28              433                  43               3       Tertiary
# 41              193                  29               1       Tertiary
# ..              ...                 ...             ...            ...
# 938             897                  45               3       Tertiary
# 945            1463                  45               3       Tertiary
# 950             497                  49               2       Tertiary
# 967            1010                   8               2       Tertiary
# 998             475                  25               0       Tertiary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 2    120.131577     East      39.13         False       -589    46-60
# 9     74.775950    North      50.57         False        192    18-30
# 11   113.461328     West     320.97         False       1108    31-45
# 28   187.738725    North     261.69         False       1580    18-30
# 41   129.793355    South      92.17         False        516    31-45
# ..          ...      ...        ...           ...        ...      ...
# 938  143.469938    North     473.07          True       2742    61-70
# 945  147.426574    South     425.88         False       1813    18-30
# 950  135.497423    South     518.70         False       3493    46-60
# 967  117.388984    South     246.22          True        884    18-30
# 998  194.429350  Central     261.95         False       1540    46-60
#
# [100 rows x 15 columns]

# %% [markdown]
# ### 17. People between 25 and 35 years old

# %%
df[(df['Age'] >= 25) & (df['Age'] <= 35)]
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 12     Ghana   28           4538                     259        6232
# 14   Nigeria   32            405                     179        4539
# 21     Ghana   32           2356                     206       14878
# 22   Nigeria   28           3444                     251        7837
# 23   Nigeria   25           2570                     134        8031
# ..       ...  ...            ...                     ...         ...
# 989  Nigeria   34           2121                     301        4939
# 990  Nigeria   29           1285                     248        1044
# 993   Rwanda   32           4131                     287       11273
# 994  Nigeria   33           1541                     288       12690
# 999    Ghana   27           2893                     207        1691
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 12              437                  50               1      Secondary
# 14              965                  32               2       Tertiary
# 21              667                  39               1        Primary
# 22              184                  38               3      Secondary
# 23              629                  36               3        Primary
# ..              ...                 ...             ...            ...
# 989              62                  29               1        Primary
# 990            1091                  31               1      Secondary
# 993             162                  37               3        Primary
# 994             278                  37               3        Primary
# 999            1026                  52               2      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 12    91.813370     West     589.94          True       4101    18-30
# 14   187.677113    North      52.65         False       -560    31-45
# 21   193.485629     West     306.28         False       1689    31-45
# 22   176.521875    South     447.72          True       3260    18-30
# 23   153.256082  Central     334.10         False       1941    18-30
# ..          ...      ...        ...           ...        ...      ...
# 989  152.021426  Central     275.73          True       2059    31-45
# 990   58.505698     East     167.05         False        194    18-30
# 993  192.326876     East     537.03          True       3969    31-45
# 994  100.331141    South     200.33          True       1263    31-45
# 999   53.625553    South     376.09         False       1867    18-30
#
# [217 rows x 15 columns]

# %% [markdown]
# ### 18. Individuals with exactly 0 hospital visits

# %%
df[df['HospitalVisits'] == 0]
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 10    Rwanda   37           2009                     218        3827
# 25     Ghana   68            852                     233       11516
# 29    Rwanda   23           3689                     232        2448
# 30   Nigeria   43           1407                     151        1570
# 31    Rwanda   21           4506                     207        3904
# ..       ...  ...            ...                     ...         ...
# 961  Nigeria   19            969                     196        4195
# 963    Ghana   25           1583                     224       12556
# 981    Ghana   55            945                     170        5926
# 988    Ghana   58           4871                     253       10141
# 998   Rwanda   50           2015                     235        3581
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 10             1082                  46               0        Primary
# 25              539                  28               0        Primary
# 29              212                  31               0      Secondary
# 30              490                  41               0        Primary
# 31             1262                  53               0        Primary
# ..              ...                 ...             ...            ...
# 961             206                  41               0       Tertiary
# 963             300                  45               0        Primary
# 981            1178                  47               0      Secondary
# 988             674                  41               0       Tertiary
# 998             475                  25               0       Tertiary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 10   188.215044     West     261.17         False        927    31-45
# 25   187.011941    South     110.76         False        313    61-70
# 29   140.450576    North     479.57         False       3477    18-30
# 30   170.458433     East     182.91         False        917    31-45
# 31   168.754265    North     585.78         False       3244    18-30
# ..          ...      ...        ...           ...        ...      ...
# 961   87.731833  Central     125.97         False        763    18-30
# 963  118.977662    South     205.79         False       1283    18-30
# 981  122.281008    North     122.85         False       -233    46-60
# 988   77.580986    North     633.23          True       4197    46-60
# 998  194.429350  Central     261.95         False       1540    46-60
#
# [136 rows x 15 columns]

# %% [markdown]
# ### 19. People who use internet more than 60 hours and live in Ghana

# %%
df[(df['InternetUsageHours'] > 60) & (df['Country'] == 'Ghana')]
# Out:
#     Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 224   Ghana   68           4333                     136       10486
# 489   Ghana   52           4487                     216        5005
# 958   Ghana   55            874                     152        2094
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 224             755                  71               2      Secondary
# 489             224                  61               2       Tertiary
# 958             881                  63               1      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 224  140.544815    North     563.29         False       3578    61-70
# 489   95.388823  Central     583.31         False       4263    46-60
# 958  131.590462     West     113.62         False         -7    46-60

# %% [markdown]
#  ### 20. People with monthly income below the mean

# %%
# How to find the mean for the dataframe
df['MonthlyIncome'].mean()
# Out:
# 2604.006

# %%
df[df['MonthlyIncome'] < df['MonthlyIncome'].mean()]
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0     Rwanda   20           1235                     166        6741
# 2     Rwanda   48            301                     238        7838
# 5      Ghana   53           2249                     262        4262
# 6     Rwanda   41           1217                     194        2338
# 8     Rwanda   23           2541                     201       12826
# ..       ...  ...            ...                     ...         ...
# 994  Nigeria   33           1541                     288       12690
# 995  Nigeria   39            489                     175       10021
# 996  Nigeria   45           1280                     132        2909
# 997   Rwanda   37           1998                     172        7364
# 998   Rwanda   50           2015                     235        3581
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0              1440                  42               2      Secondary
# 2               890                  43               2       Tertiary
# 5              1189                  48               5      Secondary
# 6               288                  42               3        Primary
# 8               490                  30               2      Secondary
# ..              ...                 ...             ...            ...
# 994             278                  37               3        Primary
# 995             220                  35               2        Primary
# 996             344                  34               2       Tertiary
# 997             238                  42               2      Secondary
# 998             475                  25               0       Tertiary
#
#      RainfallMM District
# 0     72.886134  Central
# 2    120.131577     East
# 5    195.788683  Central
# 6    177.540109     East
# 8     93.571844     West
# ..          ...      ...
# 994  100.331141    South
# 995   98.783179     West
# 996  188.507700  Central
# 997  112.602188     East
# 998  194.429350  Central
#
# [498 rows x 11 columns]

# %% [markdown]
# ## Aggregation and Grouping

# %% [markdown]
# ### 21. Average income by country

# %%
df.groupby('Country')['MonthlyIncome'].median()
# Out:
# Country
# Ghana      2589.0
# Nigeria    2421.5
# Rwanda     2768.0
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# ### 22. Total cocoa sales by country

# %%
df.groupby('Country')['CocoaSales'].sum()
# Out:
# Country
# Ghana      2828033
# Nigeria    2558449
# Rwanda     2586830
# Name: CocoaSales, dtype: int64

# %% [markdown]
# ### 23. Max transport cost by district

# %%
df.groupby('District')['TransportCosts'].max()
# Out:
# District
# Central    1499
# East       1498
# North      1499
# South      1496
# West       1495
# Name: TransportCosts, dtype: int64

# %% [markdown]
# ### 24. Mean internet usage by education level

# %%
df.groupby('EducationLevel')['InternetUsageHours'].mean()
# Out:
# EducationLevel
# Primary      39.035503
# Secondary    39.219020
# Tertiary     38.269841
# Name: InternetUsageHours, dtype: float64

# %% [markdown]
# ### 25. Hospital visits by district

# %%
df.groupby('District')['HospitalVisits'].sum()
# Out:
# District
# Central    346
# East       406
# North      353
# South      421
# West       374
# Name: HospitalVisits, dtype: int64

# %% [markdown]
# ## Column Operations and Transformation

# %% [markdown]
# ### 26. Add a new column for income in USD (assuming 1 local = 0.13 USD)

# %%
df.columns
# Out:
# Index(['Country', 'Age', 'MonthlyIncome', 'ElectricityConsumption',
#        'CocoaSales', 'TransportCosts', 'InternetUsageHours', 'HospitalVisits',
#        'EducationLevel', 'RainfallMM', 'District', 'IncomeUSD', 'HighPowerUse',
#        'NetIncome', 'AgeGroup'],
#       dtype='object')

# %%
df["Experience"]= df['MonthlyIncome']/ df['InternetUsageHours']

# %%
df.columns
# Out:
# Index(['Country', 'Age', 'MonthlyIncome', 'ElectricityConsumption',
#        'CocoaSales', 'TransportCosts', 'InternetUsageHours', 'HospitalVisits',
#        'EducationLevel', 'RainfallMM', 'District', 'IncomeUSD', 'HighPowerUse',
#        'NetIncome', 'AgeGroup', 'Experience'],
#       dtype='object')

# %%
df.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup  \
# 0   72.886134  Central     160.55         False       -205    18-30
# 1  178.878356     East     602.81         False       3656    61-70
# 2  120.131577     East      39.13         False       -589    46-60
# 3  110.633007    North     409.24          True       2088    46-60
# 4  117.422414  Central     564.72         False       3713    46-60
#
#    Experience
# 0   31.782387
# 1  119.331927
# 2    7.746153
# 3   81.012919
# 4  111.791652

# %%
df['IncomeUSD'] = df['MonthlyIncome'] * 0.13

# %%
df.columns
# Out:
# Index(['Country', 'Age', 'MonthlyIncome', 'ElectricityConsumption',
#        'CocoaSales', 'TransportCosts', 'InternetUsageHours', 'HospitalVisits',
#        'EducationLevel', 'RainfallMM', 'District', 'IncomeUSD', 'HighPowerUse',
#        'NetIncome', 'AgeGroup', 'Experience'],
#       dtype='object')

# %%
df['IncomeRWF'] = df['IncomeUSD']*1457

# %%
df.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup  \
# 0   72.886134  Central     160.55         False       -205    18-30
# 1  178.878356     East     602.81         False       3656    61-70
# 2  120.131577     East      39.13         False       -589    46-60
# 3  110.633007    North     409.24          True       2088    46-60
# 4  117.422414  Central     564.72         False       3713    46-60
#
#    Experience  IncomeRWF
# 0   29.404762  233921.35
# 1  118.897436  878294.17
# 2    7.000000   57012.41
# 3   80.717949  596262.68
# 4  140.129032  822797.04

# %% [markdown]
# ### 27. Flag high electricity consumers

# %%
df['HighPowerUse'] = df['ElectricityConsumption'] > 250

# %%
df.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup  \
# 0   72.886134  Central     160.55         False       -205    18-30
# 1  178.878356     East     602.81         False       3656    61-70
# 2  120.131577     East      39.13         False       -589    46-60
# 3  110.633007    North     409.24          True       2088    46-60
# 4  117.422414  Central     564.72         False       3713    46-60
#
#    Experience  IncomeRWF
# 0   29.404762  233921.35
# 1  118.897436  878294.17
# 2    7.000000   57012.41
# 3   80.717949  596262.68
# 4  140.129032  822797.04

# %% [markdown]
# ### 28. Total monthly expense (income - transport cost)

# %%
df['NetIncome'] = df['MonthlyIncome'] - df['TransportCosts']

# %% [markdown]
# ### 29. Create an age group column

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[18, 30, 45, 60, 70], labels=['18-30', '31-45', '46-60', '61-70'])

# %%
df.head()
# Out:
#   Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 0  Rwanda   20           1235                     166        6741
# 1   Ghana   68           4637                      98       14281
# 2  Rwanda   48            301                     238        7838
# 3  Rwanda   57           3148                     262        3587
# 4   Ghana   54           4344                     124        8876
#
#    TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 0            1440                  42               2      Secondary
# 1             981                  39               3      Secondary
# 2             890                  43               2       Tertiary
# 3            1060                  39               1      Secondary
# 4             631                  31               2      Secondary
#
#    RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup  \
# 0   72.886134  Central     160.55         False       -205    18-30
# 1  178.878356     East     602.81         False       3656    61-70
# 2  120.131577     East      39.13         False       -589    46-60
# 3  110.633007    North     409.24          True       2088    46-60
# 4  117.422414  Central     564.72         False       3713    46-60
#
#    Experience  IncomeRWF
# 0   29.404762  233921.35
# 1  118.897436  878294.17
# 2    7.000000   57012.41
# 3   80.717949  596262.68
# 4  140.129032  822797.04

# %% [markdown]
# ## Advanced Features

# %% [markdown]
# ### 30. Top 10 highest income earners

# %%
df.nlargest(5, 'MonthlyIncome')
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 795    Ghana   48           4997                     226       11589
# 876    Ghana   40           4988                     195       13662
# 214  Nigeria   65           4983                     226       12029
# 896    Ghana   31           4983                     288        3941
# 342   Rwanda   24           4976                     142       12737
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 795             319                  30               2        Primary
# 876            1441                  33               4       Tertiary
# 214             657                  43               1      Secondary
# 896            1022                  47               2      Secondary
# 342            1160                  24               1      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup  \
# 795  146.751472    North     649.61         False       4678    46-60
# 876  140.978880     East     648.44         False       3547    31-45
# 214  121.312436     East     647.79         False       4326    61-70
# 896  164.983594     West     647.79          True       3961    31-45
# 342  189.215913     West     646.88         False       3816    18-30
#
#      Experience  IncomeRWF
# 795  166.566667  946481.77
# 876  151.151515  944777.08
# 214  115.883721  943830.03
# 896  106.021277  943830.03
# 342  207.333333  942504.16

# %% [markdown]
# ### 31. Bottom 5 in internet usage

# %%
df.nsmallest(5, 'InternetUsageHours')
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 967   Rwanda   25           1894                     258       13515
# 440  Nigeria   23           1901                     180       10665
# 877  Nigeria   43           1987                     251        7782
# 275    Ghana   66           3322                     187        2445
# 449    Ghana   54            561                     202       12410
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 967            1010                   8               2       Tertiary
# 440             930                   9               3        Primary
# 877            1326                  10               2      Secondary
# 275             951                  11               2       Tertiary
# 449             552                  11               4      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 967  117.388984    South     246.22          True        884    18-30
# 440  146.411907  Central     247.13         False        971    18-30
# 877   65.559525     East     258.31          True        661    31-45
# 275   82.583615  Central     431.86         False       2371    61-70
# 449  173.180031  Central      72.93         False          9    46-60

# %% [markdown]
# ### 32. Sort by age descending

# %%
df.sort_values('ElectricityConsumption')
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 555  Nigeria   42           2857                      26        3341
# 382    Ghana   65           2864                      58        5512
# 858  Nigeria   31           4037                      65        4246
# 415    Ghana   40           3259                      68        9924
# 577  Nigeria   68           1088                      72        9721
# ..       ...  ...            ...                     ...         ...
# 547  Nigeria   34            971                     331        6552
# 158    Ghana   22           2503                     333       10095
# 75   Nigeria   22           2277                     334        4875
# 262   Rwanda   51           3189                     335       14304
# 113   Rwanda   49           4948                     336        2257
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 555            1139                  43               1      Secondary
# 382            1260                  46               1        Primary
# 858             221                  51               5      Secondary
# 415             911                  30               1      Secondary
# 577             936                  33               2      Secondary
# ..              ...                 ...             ...            ...
# 547             655                  24               4        Primary
# 158             213                  39               0      Secondary
# 75              542                  25               2       Tertiary
# 262             260                  61               1        Primary
# 113            1497                  41               2      Secondary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup  \
# 555  127.821247    North     371.41         False       1718    31-45
# 382  137.515345     West     372.32         False       1604    61-70
# 858   76.867893    North     524.81         False       3816    31-45
# 415   51.809378    North     423.67         False       2348    31-45
# 577   72.128575  Central     141.44         False        152    61-70
# ..          ...      ...        ...           ...        ...      ...
# 547   88.648553  Central     126.23          True        316    31-45
# 158   56.706040  Central     325.39          True       2290    18-30
# 75    53.096516     East     296.01          True       1735    18-30
# 262   80.790791    South     414.57          True       2929    46-60
# 113  127.795804  Central     643.24          True       3451    46-60
#
#      Experience  IncomeRWF
# 555   66.441860  541144.37
# 382   62.260870  542470.24
# 858   79.156863  764648.17
# 415  108.633333  617287.19
# 577   32.969697  206078.08
# ..          ...        ...
# 547   40.458333  183917.11
# 158   64.179487  474093.23
# 75    91.080000  431286.57
# 262   52.278689  604028.49
# 113  120.682927  937200.68
#
# [1000 rows x 17 columns]

# %%
df.sort_values('Age', ascending=False)
# Out:
#      Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 168    Ghana   69           1268                     152        2036
# 249   Rwanda   69           4026                     243       11022
# 501  Nigeria   69           3501                     137       11988
# 864   Rwanda   69           3970                     145        3017
# 368  Nigeria   69           3902                     278        2647
# ..       ...  ...            ...                     ...         ...
# 326    Ghana   18           4276                     117       11165
# 85   Nigeria   18           1573                     287       13583
# 62   Nigeria   18            961                     245        5627
# 915    Ghana   18           4167                     194        5586
# 648  Nigeria   18           2530                     218        4904
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 168             710                  49               3       Tertiary
# 249             926                  33               0      Secondary
# 501             376                  31               2       Tertiary
# 864             624                  31               0       Tertiary
# 368             506                  31               3       Tertiary
# ..              ...                 ...             ...            ...
# 326            1166                  53               1      Secondary
# 85             1389                  26               2        Primary
# 62              370                  36               2      Secondary
# 915             970                  29               0        Primary
# 648             678                  38               2       Tertiary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 168   88.515427    North     164.84         False        558    61-70
# 249  100.395546    South     523.38         False       3100    61-70
# 501  119.373532     East     455.13         False       3125    61-70
# 864  152.396732     East     516.10         False       3346    61-70
# 368  108.466298     West     507.26          True       3396    61-70
# ..          ...      ...        ...           ...        ...      ...
# 326  107.920460  Central     555.88         False       3110      NaN
# 85   165.076899    North     204.49          True        184      NaN
# 62   127.262656    South     124.93         False        591      NaN
# 915   68.984320     West     541.71         False       3197      NaN
# 648  184.178486     East     328.90         False       1852      NaN
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### 33. Sort by Country and then Income

# %%
df.sort_values(['Country', 'MonthlyIncome'], ascending=[True, False])
# Out:
#     Country  Age  MonthlyIncome  ElectricityConsumption  CocoaSales  \
# 795   Ghana   48           4997                     226       11589
# 876   Ghana   40           4988                     195       13662
# 896   Ghana   31           4983                     288        3941
# 810   Ghana   29           4976                     208        7009
# 882   Ghana   21           4924                     224        9307
# ..      ...  ...            ...                     ...         ...
# 9    Rwanda   19            389                     206        6780
# 128  Rwanda   68            327                     241        7953
# 118  Rwanda   32            313                     155        2230
# 329  Rwanda   56            309                     216        4968
# 2    Rwanda   48            301                     238        7838
#
#      TransportCosts  InternetUsageHours  HospitalVisits EducationLevel  \
# 795             319                  30               2        Primary
# 876            1441                  33               4       Tertiary
# 896            1022                  47               2      Secondary
# 810             595                  54               1      Secondary
# 882            1097                  48               3       Tertiary
# ..              ...                 ...             ...            ...
# 9               197                  53               2       Tertiary
# 128            1151                  18               1      Secondary
# 118             554                  49               1        Primary
# 329             671                  40               1        Primary
# 2               890                  43               2       Tertiary
#
#      RainfallMM District  IncomeUSD  HighPowerUse  NetIncome AgeGroup
# 795  146.751472    North     649.61         False       4678    46-60
# 876  140.978880     East     648.44         False       3547    31-45
# 896  164.983594     West     647.79          True       3961    31-45
# 810  146.412787  Central     646.88         False       4381    18-30
# 882   53.836847     West     640.12         False       3827    18-30
# ..          ...      ...        ...           ...        ...      ...
# 9     74.775950    North      50.57         False        192    18-30
# 128  126.509034    South      42.51         False       -824    61-70
# 118  133.204876    South      40.69         False       -241    31-45
# 329   62.410262     East      40.17         False       -362    46-60
# 2    120.131577     East      39.13         False       -589    46-60
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### 34. Pivot table: Average income by Country and EducationLevel

# %%
df.pivot_table(values='Age', index='Country', columns='EducationLevel', aggfunc='mean')
# Out:
# EducationLevel    Primary  Secondary   Tertiary
# Country
# Ghana           44.770370  42.298246  42.603774
# Nigeria         40.371429  43.008929  45.110092
# Rwanda          43.102041  45.099174  46.090000

# %% [markdown]
# ### 35. Export filtered dataframe

# %%
df[df['Country'] == 'Rwanda'].to_csv("rwanda_data.csv", index=False)

# %%
df[df['EducationLevel'] == 'Secondary'].to_excel("secondary sudents.xlsx")

# %% [markdown]
# ### How to access the dataset on Github

# %%
url ='https://raw.githubusercontent.com/ddaeducation/data/main/brasil-real-estate-1.csv'
brasil_data = pd.read_csv(url)

# %%
brasil_data.head()
# Out:
#    Unnamed: 0 property_type  place_with_parent_names     region  \
# 0           1     apartment  |Brasil|Alagoas|Maceió|  Northeast
# 1           2     apartment  |Brasil|Alagoas|Maceió|  Northeast
# 2           3         house  |Brasil|Alagoas|Maceió|  Northeast
# 3           4     apartment  |Brasil|Alagoas|Maceió|  Northeast
# 4           5     apartment  |Brasil|Alagoas|Maceió|  Northeast
#
#                   lat-lon  area_m2    price_usd
# 0  -9.6443051,-35.7088142      110  $187,230.85
# 1    -9.6430934,-35.70484       65   $81,133.37
# 2  -9.6227033,-35.7297953      211  $154,465.45
# 3    -9.622837,-35.719556       99  $146,013.20
# 4    -9.654955,-35.700227       55  $101,416.71

# %% [markdown]
# ## Hands-on Exercises
#
# 1. Rename all columns to lowercase with underscores.
# 2. Filter rows where density is above 200.
# 3. Create a new column: `GDP` and calculate `GDP per capita`.
# 4. Sort countries by population in descending order.
# 5. Set 'Country' as index and extract data using `.loc[]` and `.iloc[]`.
# 6. Save final cleaned data to a new CSV file.

# %% [markdown]
# ## Conclusion
#
# With Pandas, you can clean, reshape, analyze, and transform datasets efficiently. Real-world datasets from African countries can be explored more deeply with functions like `.loc`, `.iloc`, `.apply()`, and `.groupby()`.
